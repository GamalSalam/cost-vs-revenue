# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv('cost_revenue_clean.csv')

# %%
data.head()
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
x=pd.DataFrame(data['production_budget_usd'])
y=pd.DataFrame(data['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,alpha=.3)
plt.plot(x,regression.predict(x),color='red',linewidth=4)
plt.ylim(bottom=0)
plt.xlim(left=0)
plt.title('Cost vs Revenue')
plt.xlabel('Budet $')
plt.ylabel('Revenue $')
# Out:
# Text(0, 0.5, 'Revenue $')

# %%
regression= LinearRegression()
regression.fit(x,y)
# Out:
# LinearRegression()

# %%
regression.coef_ # theta 1
# Out:
# array([[3.11150918]])

# %%
regression.intercept_ # theta 0
# Out:
# array([-7236192.72913975])

# %%
regression.score(x,y) # fitting with 54% only :(
# Out:
# 0.5496485356985729

# %%
regression.rank_
# Out:
# 1

# %% [markdown]
# ## this a simple relationship between Budjet and revenue.
